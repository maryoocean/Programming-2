# %%
import urllib.request
url = 'https://habr.com/'
user_agent = 'Mozilla/5.0 (Windows NT 6.1; Win64; x64)'
req = urllib.request.Request(url, headers={'User-Agent':user_agent})
with urllib.request.urlopen(req) as response:
   html = response.read().decode('utf-8')
print(html[:210])
# Out:
# <!DOCTYPE html>
# <html lang="ru" class="no-js">
#   <head>
#     <meta http-equiv="content-type" content="text/html; charset=utf-8" />
# <meta content='width=1024' name='viewport'>
# <title>Лучшие публикации за сутки /

# %%
import re
regPostTitle = re.compile('<h2 class="post__title">.*?</h2>', flags = re.DOTALL)
#  флаг  DOTALL -- точка = символ новой строки
titles = regPostTitle.findall(html)
print(len(titles))
print(titles[:3])
# Out:
# 20
# ['<h2 class="post__title">\n    <a href="https://habr.com/company/mailru/blog/423409/" class="post__title_link">Как сделать самому Луноход</a>\n  </h2>', '<h2 class="post__title">\n    <a href="https://habr.com/post/425211/" class="post__title_link">286 и сеть</a>\n  </h2>', '<h2 class="post__title">\n    <a href="https://habr.com/company/golovanov_net/blog/425395/" class="post__title_link">10 физических фактов, которые вы должны были узнать в школе, но, возможно, не узнали</a>\n  </h2>']

# %%
new_titles = []
regTag = re.compile('<.*?>', re.DOTALL)
regSpace = re.compile('\s{2,}', re.DOTALL)
for t in titles:
    clean_t = regSpace.sub("", t)
    clean_t = regTag.sub("", clean_t)
    new_titles.append(clean_t)
for t in new_titles:
    print(t)
# Out:
# Как сделать самому Луноход
# 286 и сеть
# 10 физических фактов, которые вы должны были узнать в школе, но, возможно, не узнали
# Автор книги «Ведьмак» потребовал у CD Projekt Red минимум $16 млн
# Пятница. Бредни программиста
# Бэкендеры всех стран объединились. Рассказываем, как прошел Backend United #2
# ﻿Perl 5: как в макросах ошибки прятались
# Скоро половина звонков будет от роботов. Совет: не отвечайте (?)
# Обновление до Windows 1809 (иногда) уничтожает все файлы в профиле
# Как мы участвовали в InnovateFPGA 2018 и снова не победили
# Видео докладов с Deerploy DevOps MeetUp
# Алиса поможет разработчикам найти объекты в запросах пользователей. NER в Диалогах
# DDR SDRAM – особенности проектирования и обеспечения целостности сигнала
# Автор Python больше не руководит разработкой. Сделает это язык лучше или хуже?
# Карты из шестиугольников в Unity: неровности, реки и дороги
# HyperX Impact DDR4 — SO-DIMM, который смог! Или для чего в ноутбуке 64 ГБ памяти с частотой 3200 МГц?
# ...

# %%
for t in new_titles:
    print(t.replace("&nbsp;&rarr;", " -> "))
# Out:
# Как сделать самому Луноход
# 286 и сеть
# 10 физических фактов, которые вы должны были узнать в школе, но, возможно, не узнали
# Автор книги «Ведьмак» потребовал у CD Projekt Red минимум $16 млн
# Пятница. Бредни программиста
# Бэкендеры всех стран объединились. Рассказываем, как прошел Backend United #2
# ﻿Perl 5: как в макросах ошибки прятались
# Скоро половина звонков будет от роботов. Совет: не отвечайте (?)
# Обновление до Windows 1809 (иногда) уничтожает все файлы в профиле
# Как мы участвовали в InnovateFPGA 2018 и снова не победили
# Видео докладов с Deerploy DevOps MeetUp
# Алиса поможет разработчикам найти объекты в запросах пользователей. NER в Диалогах
# DDR SDRAM – особенности проектирования и обеспечения целостности сигнала
# Автор Python больше не руководит разработкой. Сделает это язык лучше или хуже?
# Карты из шестиугольников в Unity: неровности, реки и дороги
# HyperX Impact DDR4 — SO-DIMM, который смог! Или для чего в ноутбуке 64 ГБ памяти с частотой 3200 МГц?
# ...

# %%
import urllib.request
url = 'https://yandex.ru/pogoda/moscow'
user_agent = 'Mozilla/5.0 (Windows NT 6.1; Win64; x64)'
req = urllib.request.Request(url, headers={'User-Agent':user_agent})
with urllib.request.urlopen(req) as response:
   html = response.read().decode('utf-8')
print(html[:210])
# Out:
# <!DOCTYPE html><html class="i-ua_js_no i-ua_css_standard" lang="ru"><head><meta charset="utf-8"/><meta http-equiv="X-UA-Compatible" content="IE=edge"/><title>Прогноз погоды в Москве на 10 дней — Яндекс.Погода</

# %% [markdown]
# <span class="sunrise-sunset__text">Восход</span><i class="icon icon_sunrise icon_size_24" aria-hidden="true" data-width="24"></i></dt><dd class="sunrise-sunset__value">06:41</dd></dl><dl class="sunrise-sunset__description sunrise-sunset__description_value_sunset"><dt class="sunrise-sunset__label"><span class="sunrise-sunset__text">Закат</span><i class="icon icon_sunset icon_size_24" aria-hidden="true" data-width="24"></i></dt><dd class="sunrise-sunset__value">17:52</dd>

# %%
import re
regSunrise = re.compile('<dd class="sunrise-sunset__value">(.*?)</dd>', flags = re.DOTALL)
#  флаг  DOTALL -- точка = символ новой строки
sunrise_sunset = regSunrise.findall(html)
i = int(0)
for element in sunrise_sunset[:2]:
    print('Время {}: {}.'.format('восхода' if i == 0 else 'заката', element))
    i += 1
# Out:
# Время восхода: 06:41.
# Время заката: 17:52.

# %%
"""
import urllib.request

def download_page(pageUrl):
    try:
        page = urllib.request.urlopen(pageUrl)
        text = page.read().decode('utf-8')
    except:
        print('Error at', pageUrl)
        return

    commonUrl = 'http://dil.ie/'
"""

# %%
import urllib.request

from bs4 import BeautifulSoup
link = 'https://habr.com/'
f = urllib.request.urlopen(link)
myfile = f.read()
soup = BeautifulSoup(myfile, 'html.parser')
#print(myfile)
#print(soup.prettify())
#print(soup.get_text())
#got through all the hyperlinks...
for link in soup.find_all('a'):
#...and print them
    print(link.get('href'))
# Out:
# https://habr.com/?utm_source=tm_habrahabr&utm_medium=tm_top_panel&utm_campaign=tm_promo
# https://habr.com/flows/geektimes/
# https://toster.ru?utm_source=tm_habrahabr&utm_medium=tm_top_panel&utm_campaign=tm_promo
# https://moikrug.ru?utm_source=tm_habrahabr&utm_medium=tm_top_panel&utm_campaign=tm_promo
# https://freelansim.ru?utm_source=tm_habrahabr&utm_medium=tm_top_panel&utm_campaign=tm_promo
# /
# /
# /users/
# /hubs/
# /companies/
# /sandbox/
# https://habr.com/auth/login/
# https://habr.com/auth/register/
# https://habr.com/flows/develop/
# https://habr.com/flows/admin/
# https://habr.com/flows/design/
# https://habr.com/flows/management/
# https://habr.com/flows/marketing/
# https://habr.com/flows/geektimes/
# https://habr.com/flows/misc/
# https://habr.com/top/
# https://habr.com/all/
# https://habr.com/top/
# https://habr.com/top/weekly/
# https://habr.com/top/monthly/
# https://habr.com/top/yearly/
# https://habr.com/users/old_gamer/
# https://habr.com/post/425211/
# ...

# %%
import urllib.request 
from bs4 import BeautifulSoup
import re

url = ''
